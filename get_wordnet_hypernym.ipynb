# %%
import nltk
nltk.download('wordnet')

import json
import networkx as nx
from nltk.corpus import wordnet as wn
from transformers import AutoTokenizer

import inflect

# %% [markdown]
# # Setup

# %%
tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b")

vocab = tokenizer.get_vocab()
vocab_set = set(vocab.keys())

p = inflect.engine()

# %% [markdown]
# ## nouns

# %%
def get_all_hyponym_lemmas(synset):
    hyponyms = synset.hyponyms()
    lemmas = set()
    for hyponym in hyponyms:
        lemmas.update(lemma.name() for lemma in hyponym.lemmas())
        lemmas.update(get_all_hyponym_lemmas(hyponym))  # Recursively get lemmas from hyponyms,
    
    return lemmas

# %%
all_noun_synsets = list(wn.all_synsets(pos=wn.NOUN))
noun_lemmas = {}
for s in all_noun_synsets:
    lemmas = get_all_hyponym_lemmas(s)
    # add and remove space bc of how gemma vocab works
    lemmas = vocab_set.intersection({"▁" + l for l in lemmas})
    noun_lemmas[s.name()] = {l[1:] for l in lemmas}

large_nouns = {k: v for k, v in noun_lemmas.items() if len(v) > 5}

# %%
print(len(all_noun_synsets))
print(len(large_nouns))
# Out:
# 82115
# 2573

# %%
# Construct the hypernym inclusion graph among large categories
G_noun = nx.DiGraph()

nodes = list(large_nouns.keys())
for key in nodes:
    for path in wn.synset(key).hypernym_paths():
        # ancestors included in the cleaned set
        ancestors = [s.name() for s in path if s.name() in nodes]
        if len(ancestors) > 1:
            G_noun.add_edge(ancestors[-2],key) # first entry is itself
        else:
            print(f"no ancestors for {key}")

G_noun = nx.DiGraph(G_noun.subgraph(nodes))
# Out:
# no ancestors for entity.n.01

# %%
# if a node has only one child, and that child has only one parent, merge the two nodes
def merge_nodes(G, lemma_dict):
    topological_sorted_nodes = list(reversed(list(nx.topological_sort(G))))
    for node in topological_sorted_nodes:
        children = list(G.successors(node))
        if len(children) == 1:
            child = children[0]
            parent_lemmas_not_in_child = lemma_dict[node] - lemma_dict[child]
            if len(list(G.predecessors(child))) == 1 or len(parent_lemmas_not_in_child) <6:
                grandchildren = list(G.successors(child))
                
                if len(parent_lemmas_not_in_child) > 1:
                    if len(grandchildren) > 0:
                        lemma_dict[node + '.other'] = parent_lemmas_not_in_child
                        G.add_edge(node, node + '.other')

                # del synset_lemmas[child]
                for grandchild in grandchildren:
                    G.add_edge(node, grandchild)
                G.remove_node(child)
                print(f"merged {node} and {child}")

merge_nodes(G_noun, large_nouns)
large_nouns = {k: v for k, v in large_nouns.items() if k in G_noun.nodes()}
# Out:
# merged bovine.n.01 and cattle.n.01
# merged horse.n.01 and saddle_horse.n.01
# merged percoid_fish.n.01 and scombroid.n.01
# merged equine.n.01 and horse.n.01
# merged cat.n.01 and domestic_cat.n.01
# merged spiny-finned_fish.n.01 and percoid_fish.n.01
# merged soft-finned_fish.n.01 and cypriniform_fish.n.01
# merged globulin.n.01 and gamma_globulin.n.01
# merged hominid.n.01 and homo.n.02
# merged even-toed_ungulate.n.01 and ruminant.n.01
# merged odd-toed_ungulate.n.01 and equine.n.01
# merged canine.n.02 and dog.n.01
# merged simple_protein.n.01 and globulin.n.01
# merged malignant_tumor.n.01 and cancer.n.01
# merged tolerance.n.03 and lenience.n.03
# merged fruit_tree.n.01 and citrus.n.02
# merged primate.n.02 and hominid.n.01
# merged saurian.n.01 and lizard.n.01
# merged waterfowl.n.01 and anseriform_bird.n.01
# merged domestic_fowl.n.01 and chicken.n.02
# merged bony_fish.n.01 and teleost_fish.n.01
# merged commissioned_officer.n.01 and commissioned_military_officer.n.01
# merged doctor.n.01 and specialist.n.02
# merged carbohydrate.n.01 and polysaccharide.n.01
# merged accumulation.n.04 and store.n.02
# merged federal_department.n.01 and executive_department.n.01
# merged constituent.n.04 and construction.n.02
# merged tumor.n.01 and malignant_tumor.n.01
# merged allowance.n.06 and tolerance.n.03
# merged production.n.07 and cultivation.n.02
# merged rearrangement.n.01 and reordering.n.01
# merged extension.n.02 and spread.n.10
# merged tennis_stroke.n.01 and return.n.11
# merged homicide.n.01 and murder.n.01
# merged medical_science.n.01 and medicine.n.01
# merged boat.n.01 and small_boat.n.01
# merged apple.n.01 and eating_apple.n.01
# merged nut.n.01 and edible_nut.n.01
# merged gymnospermous_tree.n.01 and conifer.n.01
# merged grass.n.01 and cereal.n.01
# merged lepidopterous_insect.n.01 and butterfly.n.01
# merged passerine.n.01 and oscine.n.01
# merged genitor.n.01 and parent.n.01
# merged plains_indian.n.01 and sioux.n.01
# merged military_officer.n.01 and commissioned_officer.n.01
# merged enlisted_person.n.01 and soldier.n.01
# merged mariner.n.01 and officer.n.04
# merged laborer.n.01 and hired_hand.n.01
# merged medical_practitioner.n.01 and doctor.n.01
# merged mixed_drink.n.01 and cocktail.n.01
# merged liquor.n.01 and whiskey.n.01
# merged brew.n.01 and beer.n.01
# merged ester.n.01 and nucleotide.n.01
# merged net_income.n.01 and accumulation.n.04
# merged government_department.n.01 and federal_department.n.01
# merged syntagma.n.01 and constituent.n.04
# merged growth.n.06 and tumor.n.01
# merged license.n.04 and allowance.n.06
# merged industry.n.02 and production.n.07
# merged arrangement.n.06 and rearrangement.n.01
# merged felony.n.01 and larceny.n.01
# merged medical_care.n.01 and therapy.n.01
# merged outdoor_game.n.01 and field_game.n.01
# merged presentation.n.02 and performance.n.02
# merged expansion.n.01 and extension.n.02
# merged shortening.n.02 and cut.n.18
# merged air_travel.n.01 and flight.n.02
# merged walk.n.01 and gait.n.03
# merged repair.n.01 and restoration.n.02
# merged killing.n.02 and homicide.n.01
# merged completion.n.02 and consummation.n.02
# merged acting.n.01 and portrayal.n.02
# merged dancing.n.01 and social_dancing.n.01
# merged football_play.n.01 and run.n.05
# merged policy.n.02 and economic_policy.n.01
# merged actinic_radiation.n.01 and light.n.01
# merged cutter.n.06 and edge_tool.n.01
# merged brace.n.09 and crosspiece.n.02
# merged gun.n.01 and firearm.n.01
# merged self-propelled_vehicle.n.01 and motor_vehicle.n.01
# merged horse-drawn_vehicle.n.01 and carriage.n.02
# merged aircraft.n.01 and heavier-than-air_craft.n.01
# merged book.n.01 and reference_book.n.01
# merged undergarment.n.01 and underpants.n.01
# merged pome.n.01 and apple.n.01
# merged seed.n.01 and nut.n.01
# merged climber.n.01 and legume.n.01
# merged gramineous_plant.n.01 and grass.n.01
# merged angiosperm.n.01 and flower.n.01
# merged insect.n.01 and lepidopterous_insect.n.01
# merged mammal.n.01 and placental.n.01
# merged reptile.n.01 and diapsid.n.01
# merged aquatic_vertebrate.n.01 and fish.n.01
# merged lawman.n.01 and policeman.n.01
# merged guard.n.01 and watchman.n.01
# merged progenitor.n.01 and genitor.n.01
# merged forebear.n.01 and grandparent.n.01
# merged collegian.n.01 and undergraduate.n.01
# merged principal.n.05 and criminal.n.01
# merged indian.n.02 and dravidian.n.01
# merged sailor.n.01 and mariner.n.01
# merged workman.n.01 and laborer.n.01
# merged administrator.n.01 and executive.n.01
# merged male_aristocrat.n.01 and lord.n.03
# merged evaluator.n.01 and critic.n.02
# merged musician.n.01 and singer.n.01
# merged businessman.n.01 and owner.n.01
# merged health_professional.n.01 and medical_practitioner.n.01
# merged educator.n.01 and teacher.n.01
# merged fraction.n.03 and common_fraction.n.01
# merged tobacco.n.01 and roll_of_tobacco.n.01
# merged playing_card.n.01 and spot.n.13
# merged binary_compound.n.01 and water.n.01
# merged low_explosive.n.01 and firework.n.01
# merged hormone.n.01 and steroid_hormone.n.01
# merged income.n.01 and net_income.n.01
# merged fixed_charge.n.01 and fee.n.01
# merged recompense.n.01 and compensation.n.01
# merged department.n.01 and government_department.n.01
# merged line.n.23 and railway.n.01
# merged string_of_words.n.01 and syntagma.n.01
# merged theological_virtue.n.01 and religion.n.01
# merged interest.n.01 and concern.n.01
# merged injury.n.01 and wound.n.01
# merged authorization.n.04 and license.n.04
# merged mathematical_process.n.01 and arithmetic_operation.n.01
# merged arts_and_crafts.n.01 and handicraft.n.02
# merged composing.n.02 and arrangement.n.06
# merged deception.n.02 and pretense.n.01
# merged sin.n.02 and mortal_sin.n.01
# merged education.n.04 and teaching.n.01
# merged venture.n.01 and campaign.n.02
# merged enterprise.n.01 and business_activity.n.01
# merged assignment.n.05 and school_assignment.n.01
# merged treatment.n.01 and medical_care.n.01
# merged analysis.n.01 and chemical_analysis.n.01
# merged manual_labor.n.01 and application.n.03
# merged effort.n.02 and exercise.n.01
# merged water_sport.n.01 and swimming.n.01
# merged outdoor_sport.n.01 and fishing.n.01
# merged show.n.01 and presentation.n.02
# merged merrymaking.n.01 and revel.n.01
# merged maltreatment.n.01 and persecution.n.01
# merged gratification.n.02 and indulgence.n.03
# merged joining.n.01 and fastening.n.02
# merged change_of_course.n.01 and turn.n.02
# merged stroke.n.12 and blow.n.01
# merged disturbance.n.05 and commotion.n.02
# merged transportation.n.02 and delivery.n.01
# merged maneuver.n.03 and stroke.n.01
# merged locomotion.n.02 and walk.n.01
# merged move.n.01 and maneuver.n.04
# merged success.n.02 and score.n.10
# merged mathematics.n.01 and pure_mathematics.n.01
# merged play.n.03 and football_play.n.01
# merged right.n.01 and legal_right.n.01
# merged feature.n.01 and aspect.n.01
# merged kind.n.01 and type.n.01
# merged argumentation.n.02 and policy.n.02
# merged emblem.n.02 and badge.n.01
# merged vogue.n.01 and fashion.n.03
# merged monster.n.01 and mythical_monster.n.01
# merged electromagnetic_radiation.n.01 and actinic_radiation.n.01
# merged precipitation.n.03 and rain.n.01
# merged tube.n.01 and pipe.n.02
# merged kitchen_utensil.n.01 and cooking_utensil.n.01
# merged cutting_implement.n.01 and cutter.n.06
# merged seat.n.03 and chair.n.01
# merged bedroom_furniture.n.01 and bed.n.01
# merged golf_equipment.n.01 and golf_club.n.02
# merged photographic_paper.n.01 and film.n.03
# merged man.n.10 and chessman.n.01
# merged fastener.n.02 and pin.n.09
# merged stringed_instrument.n.01 and bowed_stringed_instrument.n.01
# merged recording.n.03 and sound_recording.n.01
# merged rotating_mechanism.n.01 and circle.n.08
# merged mechanical_device.n.01 and machine.n.04
# merged motor.n.01 and engine.n.01
# merged computer.n.01 and digital_computer.n.01
# merged scientific_instrument.n.01 and magnifier.n.01
# merged measuring_instrument.n.01 and timepiece.n.01
# merged transducer.n.01 and electro-acoustic_transducer.n.01
# merged reactor.n.01 and coil.n.06
# merged circuit.n.01 and computer_circuit.n.01
# merged plate.n.14 and armor_plate.n.01
# merged appliance.n.02 and home_appliance.n.01
# merged woman's_clothing.n.01 and dress.n.01
# merged headdress.n.01 and hat.n.01
# merged footwear.n.01 and hosiery.n.01
# merged bulbous_plant.n.01 and liliaceous_plant.n.01
# merged vine.n.01 and climber.n.01
# merged spermatophyte.n.01 and angiosperm.n.01
# merged offspring.n.01 and child.n.02
# merged student.n.01 and collegian.n.01
# merged supporter.n.01 and enthusiast.n.01
# merged amerindian.n.01 and indian.n.01
# merged asian.n.01 and indian.n.02
# merged employee.n.01 and workman.n.01
# merged assistant.n.01 and attendant.n.01
# merged unpleasant_person.n.01 and unpleasant_woman.n.01
# merged entrant.n.03 and intruder.n.01
# merged christian.n.01 and protestant.n.01
# merged superior.n.01 and supervisor.n.01
# merged politician.n.01 and legislator.n.01
# merged head.n.04 and administrator.n.01
# merged aristocrat.n.01 and male_aristocrat.n.01
# merged spiritual_leader.n.01 and clergyman.n.01
# merged scholar.n.01 and philosopher.n.01
# merged american.n.03 and north_american.n.01
# merged european.n.01 and italian.n.01
# merged woman.n.01 and girl.n.01
# merged authority.n.03 and evaluator.n.01
# merged artist.n.01 and musician.n.02
# merged articulator.n.01 and speaker.n.01
# merged bone.n.01 and tooth.n.01
# merged coinage.n.01 and coin.n.01
# merged paper_money.n.01 and bill.n.03
# merged rational_number.n.01 and fraction.n.03
# merged type.n.04 and font.n.01
# merged written_agreement.n.01 and contract.n.01
# merged act.n.01 and decree.n.01
# merged negotiable_instrument.n.01 and draft.n.01
# merged line.n.05 and heading.n.01
# merged software.n.01 and program.n.07
# merged indic.n.01 and sanskrit.n.01
# merged latin.n.01 and romance.n.03
# merged paint.n.01 and water-base_paint.n.01
# merged card.n.01 and playing_card.n.01
# merged body_waste.n.01 and fecal_matter.n.01
# merged explosive.n.01 and low_explosive.n.01
# merged animal_product.n.01 and animal_skin.n.01
# merged secretion.n.02 and hormone.n.01
# merged tax.n.01 and indirect_tax.n.01
# merged financial_gain.n.01 and income.n.01
# merged charge.n.03 and fixed_charge.n.01
# merged division.n.04 and department.n.01
# merged carrier.n.05 and line.n.23
# merged string.n.05 and string_of_words.n.01
# merged brown.n.01 and light_brown.n.01
# merged simple_closed_curve.n.01 and loop.n.02
# merged confusion.n.02 and perplexity.n.01
# merged curiosity.n.01 and interest.n.01
# merged mental_disorder.n.01 and affective_disorder.n.01
# merged discontentment.n.01 and dissatisfaction.n.01
# merged improvement.n.01 and revival.n.01
# merged mishap.n.02 and accident.n.01
# merged report.n.02 and gossip.n.02
# merged punishment.n.01 and corporal_punishment.n.01
# merged support.n.02 and blessing.n.01
# merged medical_procedure.n.01 and operation.n.06
# merged calculation.n.01 and mathematical_process.n.01
# merged survival.n.03 and custom.n.01
# merged repetition.n.02 and copying.n.01
# merged art.n.02 and arts_and_crafts.n.01
# merged creating_by_mental_acts.n.01 and composing.n.02
# merged creating_from_raw_materials.n.01 and construction.n.01
# merged sensing.n.02 and look.n.02
# merged self-denial.n.02 and abstinence.n.02
# merged grasping.n.02 and clasp.n.02
# merged falsification.n.02 and deception.n.02
# merged profession.n.02 and education.n.04
# merged duty.n.02 and function.n.03
# merged parlor_game.n.01 and board_game.n.01
# merged entertainment.n.01 and show.n.01
# merged celebration.n.02 and merrymaking.n.01
# merged mistreatment.n.01 and maltreatment.n.01
# merged press.n.09 and compression.n.04
# merged satisfaction.n.05 and gratification.n.02
# merged change_of_direction.n.01 and change_of_course.n.01
# merged decision.n.01 and move.n.01
# merged attainment.n.01 and success.n.02
# merged clock_time.n.01 and hour.n.02
# merged spirit.n.04 and evil_spirit.n.01
# merged visual_percept.n.01 and view.n.02
# merged hypothesis.n.02 and assumption.n.02
# merged law.n.04 and principle.n.04
# merged law.n.03 and principle.n.03
# merged abstraction.n.01 and right.n.01
# merged property.n.04 and feature.n.01
# merged category.n.02 and kind.n.01
# merged understanding.n.01 and insight.n.03
# merged consideration.n.01 and contemplation.n.02
# merged symbol.n.02 and emblem.n.02
# merged taste.n.03 and vogue.n.01
# merged appraisal.n.01 and evaluation.n.02
# merged sensitivity.n.01 and exteroception.n.01
# merged radiation.n.01 and electromagnetic_radiation.n.01
# merged storm.n.01 and windstorm.n.01
# merged solanaceous_vegetable.n.01 and pepper.n.04
# merged hallucinogen.n.01 and lysergic_acid_diethylamide.n.01
# merged soft_drug.n.01 and cannabis.n.02
# merged hard_drug.n.01 and cocaine.n.01
# merged snack_food.n.01 and sandwich.n.01
# merged sweet.n.03 and candy.n.01
# merged dessert.n.01 and frozen_dessert.n.01
# merged surface.n.02 and side.n.04
# merged limit.n.04 and edge.n.06
# merged conduit.n.01 and tube.n.01
# merged barrier.n.01 and movable_barrier.n.01
# merged institution.n.02 and penal_institution.n.01
# merged telecommunication.n.01 and broadcasting.n.02
# merged print_media.n.01 and press.n.02
# merged cosmetic.n.01 and makeup.n.01
# merged network.n.05 and computer_network.n.01
# merged utensil.n.01 and kitchen_utensil.n.01
# merged stick.n.01 and club.n.03
# merged bar.n.03 and lever.n.01
# merged photographic_equipment.n.01 and photographic_paper.n.01
# merged gear.n.04 and stable_gear.n.01
# merged electronic_equipment.n.01 and set.n.13
# merged support.n.10 and structural_member.n.01
# merged strengthener.n.01 and brace.n.09
# merged source_of_illumination.n.01 and lamp.n.01
# merged restraint.n.06 and fastener.n.02
# merged memory_device.n.01 and recording.n.03
# merged electronic_device.n.01 and display.n.06
# merged vessel.n.03 and bottle.n.01
# merged case.n.05 and baggage.n.01
# merged marking.n.02 and spot.n.05
# merged jewelry.n.01 and jewel.n.01
# merged model.n.04 and figure.n.04
# merged document.n.02 and letter.n.01
# merged work.n.02 and publication.n.01
# merged plastic_art.n.01 and sculpture.n.01
# merged graphic_art.n.01 and painting.n.01
# merged shield.n.01 and plate.n.14
# merged white_goods.n.02 and linen.n.03
# merged durables.n.01 and appliance.n.02
# merged tableware.n.01 and crockery.n.01
# merged stalk.n.02 and branch.n.02
# merged reproductive_structure.n.01 and fruit.n.01
# merged chordate.n.01 and vertebrate.n.01
# merged young.n.01 and young_mammal.n.01
# merged user.n.01 and consumer.n.01
# merged simpleton.n.01 and fool.n.01
# merged preserver.n.03 and defender.n.01
# merged party.n.05 and litigant.n.01
# merged owner.n.02 and holder.n.02
# merged killer.n.01 and murderer.n.01
# merged good_person.n.01 and benefactor.n.01
# merged follower.n.01 and disciple.n.01
# merged enrollee.n.01 and student.n.01
# merged acquirer.n.01 and recipient.n.01
# merged white.n.01 and semite.n.01
# merged unskilled_person.n.01 and novice.n.02
# merged peer.n.01 and associate.n.01
# merged nonworker.n.01 and idler.n.01
# merged female.n.02 and woman.n.01
# merged entertainer.n.01 and performer.n.01
# merged disputant.n.01 and reformer.n.01
# merged muscle.n.01 and skeletal_muscle.n.01
# merged connective_tissue.n.01 and bone.n.01
# merged orifice.n.01 and rima.n.01
# merged vessel.n.01 and blood_vessel.n.01
# merged dry_unit.n.01 and british_capacity_unit.n.01
# merged liquid_unit.n.01 and united_states_liquid_unit.n.01
# merged real_number.n.01 and rational_number.n.01
# merged digit.n.01 and two.n.01
# merged day_of_the_week.n.01 and weekday.n.01
# merged day.n.03 and holiday.n.02
# merged hours.n.01 and shift.n.03
# merged popular_music.n.01 and jazz.n.02
# merged religious_music.n.01 and religious_song.n.01
# merged passage.n.02 and excerpt.n.01
# merged versification.n.02 and poetic_rhythm.n.01
# merged nonfiction.n.01 and article.n.01
# merged postulate.n.01 and premise.n.01
# merged charge.n.02 and accusation.n.01
# merged commercial_document.n.01 and statement.n.07
# merged text.n.01 and line.n.05
# merged fiction.n.01 and story.n.02
# merged code.n.03 and software.n.01
# merged uralic.n.01 and finno-ugric.n.01
# merged indo-iranian.n.01 and indic.n.01
# merged italic.n.02 and latin.n.01
# merged germanic.n.01 and west_germanic.n.01
# merged balto-slavic.n.01 and slavic.n.01
# merged malayo-polynesian.n.01 and western_malayo-polynesian.n.01
# merged kadai.n.01 and tai.n.02
# merged sinitic.n.01 and chinese.n.01
# merged appellation.n.01 and title.n.06
# merged catalyst.n.01 and enzyme.n.01
# merged metallic_element.n.01 and noble_metal.n.01
# merged fiber.n.01 and natural_fiber.n.01
# merged discharge.n.03 and exudate.n.01
# merged earth.n.02 and soil.n.02
# merged animal_material.n.01 and animal_product.n.01
# merged rock.n.02 and igneous_rock.n.01
# merged mineral.n.01 and quartz.n.02
# merged levy.n.01 and tax.n.01
# merged wealth.n.03 and treasure.n.01
# merged speculation.n.03 and gamble.n.01
# merged gain.n.04 and financial_gain.n.01
# merged interest.n.05 and security_interest.n.01
# merged gift.n.01 and aid.n.03
# merged part_of_speech.n.01 and major_form_class.n.01
# merged military_unit.n.01 and army_unit.n.01
# merged commercial_enterprise.n.01 and industry.n.01
# merged educational_institution.n.01 and school.n.01
# merged lineage.n.01 and family.n.04
# merged sequence.n.01 and string.n.05
# merged quantity.n.02 and abundance.n.01
# merged brightness.n.01 and radiance.n.02
# merged virtue.n.04 and cardinal_virtue.n.01
# merged opening.n.01 and crack.n.01
# merged closed_curve.n.01 and simple_closed_curve.n.01
# merged depression.n.08 and groove.n.01
# merged dishonor.n.01 and shame.n.02
# merged decay.n.04 and deterioration.n.01
# merged pathological_state.n.01 and ill_health.n.01
# merged arousal.n.02 and emotional_arousal.n.01
# merged misfortune.n.02 and adversity.n.01
# merged good_fortune.n.01 and prosperity.n.02
# merged longing.n.01 and discontentment.n.01
# merged hate.n.01 and hostility.n.03
# merged joy.n.01 and exhilaration.n.01
# merged anger.n.01 and annoyance.n.02
# merged party.n.04 and dance.n.04
# merged impact.n.01 and blow.n.02
# merged electrical_discharge.n.01 and atmospheric_electricity.n.01
# merged result.n.03 and consequence.n.02
# merged origin.n.03 and cause.n.01
# merged affliction.n.03 and attack.n.07
# merged informing.n.02 and report.n.02
# merged objection.n.02 and complaint.n.03
# merged disagreement.n.03 and dispute.n.01
# merged agreement.n.06 and assent.n.01
# merged sharing.n.04 and giving.n.01
# merged assembly.n.06 and meeting.n.04
# merged conflict.n.01 and fight.n.02
# merged military_action.n.01 and battle.n.01
# merged aid.n.02 and support.n.02
# merged ceremony.n.03 and religious_ceremony.n.01
# merged grouping.n.02 and collection.n.04
# merged organization.n.06 and order.n.15
# merged representation.n.10 and pictorial_representation.n.01
# merged education.n.01 and course.n.01
# merged sensory_activity.n.01 and sensing.n.02
# merged attempt.n.01 and test.n.05
# merged role.n.04 and position.n.09
# merged writing.n.05 and cryptography.n.02
# merged music.n.03 and vocal_music.n.02
# merged practice.n.01 and mistreatment.n.01
# merged mistake.n.01 and blunder.n.01
# merged escape.n.01 and evasion.n.04
# merged rescue.n.01 and redemption.n.01
# merged push.n.01 and press.n.09
# merged throw.n.01 and pitch.n.02
# merged sending.n.01 and transmission.n.01
# merged aggression.n.03 and plundering.n.01
# merged choice.n.02 and decision.n.01
# merged arrival.n.02 and entrance.n.03
# merged negative_stimulus.n.01 and concern.n.04
# merged reading.n.03 and clock_time.n.01
# merged supernaturalism.n.01 and magic.n.01
# merged doctrine.n.01 and philosophical_doctrine.n.01
# merged appearance.n.04 and illusion.n.01
# merged percept.n.01 and visual_percept.n.01
# merged generalization.n.02 and principle.n.01
# merged plan.n.01 and plan_of_action.n.01
# merged design.n.02 and configuration.n.01
# merged linguistic_process.n.02 and reading.n.01
# merged knowing.n.01 and understanding.n.01
# merged decision_making.n.01 and option.n.02
# merged discrimination.n.02 and taste.n.03
# merged classification.n.03 and appraisal.n.01
# merged attention.n.05 and concentration.n.05
# merged method.n.01 and system.n.04
# merged wisdom.n.03 and sagacity.n.01
# merged oxidation.n.01 and combustion.n.01
# merged mechanical_phenomenon.n.01 and resistance.n.02
# merged energy.n.01 and radiation.n.01
# merged cut.n.06 and cut_of_beef.n.01
# merged bird.n.02 and poultry.n.02
# merged stimulant.n.02 and amphetamine.n.01
# merged psychoactive_drug.n.01 and hallucinogen.n.01
# merged dish.n.02 and snack_food.n.01
# merged dainty.n.01 and sweet.n.03
# merged course.n.07 and dessert.n.01
# merged ingredient.n.03 and flavorer.n.01
# merged section.n.03 and vicinity.n.01
# merged end.n.01 and point.n.15
# merged lumber.n.01 and strip.n.05
# merged road.n.01 and thoroughfare.n.01
# merged path.n.02 and walk.n.05
# merged access.n.03 and entrance.n.01
# merged horizontal_surface.n.01 and platform.n.01
# merged shelter.n.01 and tent.n.01
# merged defensive_structure.n.01 and fortification.n.01
# merged building_complex.n.01 and plant.n.01
# merged band.n.07 and hoop.n.02
# merged cord.n.01 and thread.n.01
# merged toiletry.n.01 and cosmetic.n.01
# merged furnishing.n.02 and furniture.n.01
# merged connection.n.03 and junction.n.04
# merged adornment.n.01 and jewelry.n.01
# merged needlework.n.01 and sewing.n.02
# merged footwear.n.02 and shoe.n.01
# merged drygoods.n.01 and white_goods.n.02
# merged ware.n.01 and tableware.n.01
# merged sheath.n.02 and husk.n.02
# merged microorganism.n.01 and protoctist.n.01
# merged plant.n.02 and vascular_plant.n.01
# merged erectile_organ.n.01 and penis.n.01
# merged sense_organ.n.01 and chemoreceptor.n.01
# merged contractile_organ.n.01 and muscle.n.01
# merged cavity.n.04 and sac.n.04
# merged tube.n.04 and vessel.n.01
# merged extremity.n.05 and vertebrate_foot.n.01
# merged extremity.n.01 and limb.n.01
# merged taste.n.05 and morsel.n.02
# merged helping.n.01 and drink.n.01
# merged complex_number.n.01 and real_number.n.01
# merged constant.n.02 and coefficient.n.01
# merged calendar_month.n.01 and gregorian_calendar_month.n.01
# merged time_off.n.01 and leisure.n.01
# merged work_time.n.01 and hours.n.01
# merged conversation.n.01 and talk.n.01
# merged section.n.01 and passage.n.02
# merged form.n.10 and versification.n.02
# merged prose.n.01 and nonfiction.n.01
# merged identification.n.02 and positive_identification.n.01
# merged award.n.02 and academic_degree.n.01
# merged comment.n.02 and note.n.07
# merged falsehood.n.01 and misrepresentation.n.01
# merged proposition.n.01 and postulate.n.01
# merged declaration.n.01 and assertion.n.01
# merged pleading.n.01 and charge.n.02
# merged disparagement.n.01 and defamation.n.01
# merged criticism.n.01 and rebuke.n.01
# merged news.n.02 and report.n.03
# merged database.n.01 and list.n.01
# merged question.n.02 and problem.n.02
# merged matter.n.06 and text.n.01
# merged coding_system.n.01 and code.n.03
# merged niger-kordofanian.n.01 and niger-congo.n.01
# merged afroasiatic.n.01 and chad.n.04
# merged austronesian.n.02 and malayo-polynesian.n.01
# merged frequency.n.01 and radio_frequency.n.01
# merged quotient.n.01 and proportion.n.01
# merged phone.n.02 and consonant.n.01
# merged name.n.01 and appellation.n.01
# merged syllable.n.01 and solfa_syllable.n.01
# merged fluid.n.01 and liquid.n.01
# merged activator.n.01 and catalyst.n.01
# merged body_substance.n.01 and liquid_body_substance.n.01
# merged compass_point.n.01 and cardinal_compass_point.n.01
# merged spacing.n.02 and distance.n.01
# merged charge.n.08 and levy.n.01
# merged material_resource.n.01 and wealth.n.03
# merged investment.n.02 and speculation.n.03
# merged sum.n.01 and gain.n.04
# merged share.n.01 and interest.n.05
# merged loss.n.01 and financial_loss.n.01
# merged outgo.n.01 and cost.n.01
# merged acquisition.n.02 and gift.n.01
# merged real_property.n.01 and estate.n.02
# merged alliance.n.03 and world_organization.n.01
# merged force.n.04 and military_service.n.01
# merged polity.n.02 and government.n.01
# merged assembly.n.04 and legislature.n.01
# merged genealogy.n.01 and lineage.n.01
# merged occupational_group.n.01 and profession.n.01
# merged upper_class.n.01 and elite.n.01
# merged series.n.01 and sequence.n.01
# merged intensity.n.02 and force.n.03
# merged duration.n.03 and permanence.n.01
# merged temporal_arrangement.n.01 and timing.n.01
# merged light.n.07 and brightness.n.01
# merged liability.n.03 and disadvantage.n.01
# merged value.n.02 and importance.n.01
# merged unrighteousness.n.01 and dishonesty.n.01
# merged similarity.n.01 and likeness.n.01
# merged animation.n.03 and liveliness.n.02
# merged disposition.n.01 and composure.n.01
# merged spirit.n.03 and courage.n.01
# merged curve.n.01 and closed_curve.n.01
# merged plane_figure.n.01 and polygon.n.01
# merged concave_shape.n.01 and depression.n.08
# merged convex_shape.n.01 and projection.n.05
# merged possibility.n.02 and opportunity.n.01
# merged holy_order.n.01 and priest.n.01
# merged subjugation.n.01 and confinement.n.03
# merged environment.n.01 and sphere.n.01
# merged unsoundness.n.01 and decay.n.04
# merged sanitary_condition.n.01 and dirtiness.n.01
# merged difficulty.n.03 and situation.n.03
# merged happiness.n.02 and contentment.n.01
# merged pain.n.02 and suffering.n.04
# merged desire.n.01 and longing.n.01
# merged contest.n.01 and race.n.02
# merged contact.n.04 and impact.n.01
# merged success.n.01 and victory.n.01
# merged discharge.n.01 and electrical_discharge.n.01
# merged periodic_event.n.01 and repeat.n.01
# merged hindrance.n.03 and prevention.n.01
# merged rejection.n.01 and banishment.n.02
# merged touch.n.05 and hit.n.02
# merged running_away.n.01 and escape.n.01
# merged recovery.n.03 and rescue.n.01
# merged implementation.n.02 and means.n.01
# merged discovery.n.01 and determination.n.01
# merged departure.n.01 and withdrawal.n.03
# merged orientation.n.02 and political_orientation.n.01
# merged inclination.n.01 and partiality.n.02
# merged stimulation.n.02 and negative_stimulus.n.01
# merged knowledge_domain.n.01 and discipline.n.01
# merged arrangement.n.03 and design.n.02
# merged determinant.n.01 and influence.n.03
# merged difficulty.n.02 and hindrance.n.01
# merged creativity.n.01 and imagination.n.01
# merged discharge.n.04 and elimination.n.02
# merged reaction.n.03 and reflex.n.01
# merged consumption.n.01 and eating.n.01
# merged chemical_reaction.n.01 and oxidation.n.01
# merged chemical_phenomenon.n.01 and state_of_matter.n.01
# merged accessory.n.02 and fitting.n.02
# merged layer.n.02 and stratum.n.01
# merged topographic_point.n.01 and junction.n.01
# merged geographic_point.n.01 and workplace.n.01
# merged path.n.03 and direction.n.01
# merged strip.n.02 and band.n.07
# merged padding.n.01 and pad.n.04
# merged opening.n.10 and hole.n.02
# merged fixture.n.01 and plumbing_fixture.n.01
# merged article.n.02 and ware.n.01
# merged celestial_body.n.01 and star.n.01
# merged body.n.04 and particle.n.02
# merged cell.n.02 and somatic_cell.n.01
# merged joint.n.01 and synovial_joint.n.01
# merged tissue.n.01 and animal_tissue.n.01
# merged standard.n.01 and medium_of_exchange.n.01
# merged record.n.07 and register.n.03
# merged manner_of_speaking.n.01 and prosody.n.01
# merged device.n.02 and rhetorical_device.n.01
# merged demonstration.n.05 and expression.n.02
# merged gesture.n.02 and facial_expression.n.01
# merged indicator.n.02 and reference_point.n.01
# merged promotion.n.01 and ad.n.01
# merged direction.n.06 and rule.n.03
# merged disrespect.n.01 and disparagement.n.01
# merged disapproval.n.02 and criticism.n.01
# merged acknowledgment.n.03 and greeting.n.01
# merged subject.n.01 and question.n.02
# merged request.n.01 and demand.n.01
# merged artificial_language.n.01 and programming_language.n.01
# merged rate.n.01 and frequency.n.01
# merged ratio.n.01 and quotient.n.01
# merged function.n.01 and trigonometric_function.n.01
# merged direction.n.02 and compass_point.n.01
# merged placement.n.01 and spacing.n.02
# merged liabilities.n.01 and charge.n.08
# merged property.n.01 and real_property.n.01
# merged class.n.01 and grammatical_category.n.01
# merged movement.n.04 and artistic_movement.n.01
# merged political_system.n.01 and autocracy.n.01
# merged set.n.05 and clique.n.01
# merged kin.n.02 and genealogy.n.01
# merged class.n.03 and upper_class.n.01
# merged ordering.n.01 and series.n.01
# merged formation.n.01 and line.n.01
# merged degree.n.01 and intensity.n.02
# merged spatial_property.n.01 and shape.n.01
# merged tactile_property.n.01 and texture.n.01
# merged disposition.n.04 and tendency.n.03
# merged consistency.n.01 and solidity.n.01
# merged heredity.n.02 and inheritance.n.03
# merged ability.n.01 and capability.n.01
# merged bad.n.01 and liability.n.03
# merged worth.n.02 and value.n.02
# merged immobility.n.02 and immovability.n.01
# merged difference.n.01 and inequality.n.01
# merged sameness.n.01 and similarity.n.01
# merged characteristic.n.02 and compatibility.n.02
# merged wisdom.n.02 and discretion.n.05
# merged discipline.n.03 and restraint.n.02
# merged resoluteness.n.01 and determination.n.02
# merged drive.n.05 and aggressiveness.n.01
# merged activeness.n.02 and animation.n.03
# merged nature.n.04 and disposition.n.01
# merged character.n.03 and spirit.n.03
# merged amorphous_shape.n.01 and space.n.02
# merged angular_shape.n.01 and fold.n.01
# merged union.n.04 and connection.n.02
# merged separation.n.01 and isolation.n.01
# merged illumination.n.02 and dark.n.01
# merged order.n.03 and harmony.n.03
# merged being.n.01 and possibility.n.02
# merged relationship.n.02 and sexual_relationship.n.01
# merged condition.n.03 and fortune.n.04
# merged structure.n.03 and arrangement.n.03
# merged process.n.04 and defense_mechanism.n.01
# merged data_processing.n.01 and operation.n.04
# merged temperature_change.n.01 and heating.n.01
# merged chemical_process.n.01 and chemical_reaction.n.01
# merged crystal.n.01 and gem.n.02
# merged fuel.n.01 and fossil_fuel.n.01
# merged natural_depression.n.01 and valley.n.01
# merged appendage.n.03 and handle.n.01
# merged molecule.n.01 and macromolecule.n.01
# merged time_interval.n.01 and pause.n.01
# merged time_unit.n.01 and day.n.01
# merged system_of_measurement.n.01 and standard.n.01
# merged document.n.03 and record.n.07
# merged voice.n.02 and singing_voice.n.01
# merged linguistic_relation.n.01 and grammatical_relation.n.01
# merged mathematical_relation.n.01 and function.n.01
# merged community.n.06 and biome.n.01
# merged inheritance.n.04 and upbringing.n.01
# merged processing.n.01 and data_processing.n.01
# merged increase.n.03 and accretion.n.01
# merged decrease.n.02 and decline.n.01
# merged land.n.02 and wetland.n.01

# %%
# make a gemma specific version
def _noun_to_gemma_vocab_elements(word):
    word = word.lower()
    plural = p.plural(word)
    add_cap_and_plural = [word, word.capitalize(), plural, plural.capitalize()]
    add_space = ["▁" + w for w in add_cap_and_plural]
    return vocab_set.intersection(add_space)

### save the data
# with open('data/noun_synsets_wordnet_gemma.json', 'w') as f:
#     for synset, lemmas in large_nouns.items():
#         gemma_words = []
#         for w in lemmas:
#             gemma_words.extend(_noun_to_gemma_vocab_elements(w))

#         f.write(json.dumps({synset: gemma_words}) + "\n")
        
# nx.write_adjlist(G_noun, "data/noun_synsets_wordnet_hypernym_graph.adjlist")

#### After this, we utilized the GPT-4 API to obtain cleaner features. The code is omitted here.

# %% [markdown]
# ## verbs

# %%
all_verb_synsets = list(wn.all_synsets(pos=wn.VERB))

G_verb = nx.DiGraph()
verb_leaves = [s.name() for s in all_verb_synsets if len(s.hyponyms()) == 0]
for leaf in verb_leaves:
    for path in wn.synset(leaf).hypernym_paths():
        for i in range(len(path) - 1):
            G_verb.add_edge(path[i].name(), path[i+1].name())

verb_lemmas = {}
sorted_verb_synsets = list(reversed(list(nx.topological_sort(G_verb))))
for s in sorted_verb_synsets:
    # add and remove "▁" bc of how gemma vocab works
    verb_lemmas[s] = vocab_set.intersection(["▁" + lemma.name() for lemma in wn.synset(s).lemmas()])
    verb_lemmas[s] = {lemma[1:] for lemma in verb_lemmas[s]}
    for child in G_verb.successors(s):
        verb_lemmas[s].update(verb_lemmas[child])

large_verbs = {k: v for k, v in verb_lemmas.items() if len(v) > 5}

# %%
G_verb = nx.DiGraph(G_verb.subgraph(list(large_verbs.keys())))
merge_nodes(G_verb, verb_lemmas)
large_verbs = {k: v for k, v in large_verbs.items() if k in G_verb.nodes()}
# Out:
# merged provoke.v.03 and entice.v.01
# merged challenge.v.02 and provoke.v.03
# merged set_forth.v.01 and describe.v.01
# merged mean.v.01 and typify.v.02
# merged invite.v.04 and challenge.v.02
# merged back.v.01 and guarantee.v.04
# merged broach.v.01 and cover.v.05
# merged rede.v.02 and urge.v.01
# merged elaborate.v.01 and set_forth.v.01
# merged suppress.v.01 and hush.v.02
# merged approve.v.01 and back.v.01
# merged deceive.v.01 and cheat.v.03
# merged cheat.v.01 and overcharge.v.01
# merged argue.v.02 and oppose.v.01
# merged clarify.v.01 and elaborate.v.01
# merged deceive.v.02 and gull.v.02
# merged overstate.v.01 and boast.v.01
# merged repeat.v.01 and sum_up.v.01
# merged bespeak.v.01 and bode.v.01
# merged impart.v.01 and convey.v.01
# merged oppose.v.06 and protest.v.02
# merged recognize.v.09 and honor.v.01
# merged appeal.v.02 and plead.v.01
# merged ask.v.02 and request.v.02
# merged allocate.v.01 and award.v.01
# merged house.v.02 and lodge.v.04
# merged ask.v.05 and question.v.03
# merged converse.v.01 and argue.v.02
# merged talk_of.v.01 and hash_out.v.01
# merged indicate.v.03 and read.v.08
# merged testify.v.02 and attest.v.01
# merged explain.v.01 and clarify.v.01
# merged develop.v.10 and grow.v.03
# merged grate.v.04 and chew.v.01
# merged refute.v.01 and oppose.v.06
# merged trust.v.01 and count.v.08
# merged prize.v.01 and recognize.v.09
# merged register.v.01 and enroll.v.01
# merged deprive.v.02 and impoverish.v.01
# merged cleanse.v.01 and wash.v.02
# merged defend.v.01 and apologize.v.02
# merged contract.v.01 and sign.v.03
# merged notch.v.01 and score.v.02
# merged assign.v.02 and allocate.v.01
# merged shelter.v.01 and house.v.02
# merged restrain.v.01 and control.v.02
# merged wrong.v.01 and victimize.v.01
# merged disrespect.v.01 and transgress.v.01
# merged write.v.02 and rewrite.v.01
# merged address.v.01 and ask.v.05
# merged carry.v.04 and quantify.v.02
# merged lean.v.01 and slope.v.01
# merged break_up.v.16 and grate.v.04
# merged devolve.v.03 and tire.v.01
# merged guess.v.02 and predict.v.01
# merged classify.v.01 and group.v.01
# merged assume.v.01 and presuppose.v.01
# merged disown.v.02 and refute.v.01
# merged believe.v.01 and trust.v.01
# merged cancel.v.03 and revoke.v.02
# merged satisfy.v.01 and suffice.v.01
# merged withhold.v.01 and deprive.v.02
# merged write.v.07 and print.v.04
# merged thin_out.v.01 and snip.v.02
# merged fill.v.09 and close.v.15
# merged comment.v.01 and knock.v.06
# merged argue.v.01 and defend.v.01
# merged embarrass.v.01 and confuse.v.03
# merged inspire.v.01 and encourage.v.02
# merged replace.v.01 and change.v.06
# merged boat.v.01 and sail.v.03
# merged operate.v.03 and fly.v.03
# merged fling.v.01 and flip.v.06
# merged communicate.v.01 and request.v.01
# merged aim.v.01 and target.v.01
# merged incise.v.01 and notch.v.01
# merged bet.v.02 and bet_on.v.01
# merged entrust.v.01 and consign.v.02
# merged distribute.v.01 and assign.v.02
# merged pay.v.01 and spend.v.02
# merged inhibit.v.04 and restrain.v.01
# merged delay.v.02 and postpone.v.01
# merged fight.v.03 and tug.v.02
# merged refuse.v.01 and disobey.v.01
# merged transact.v.01 and deal.v.06
# merged socialize.v.01 and entertain.v.01
# merged sink.v.01 and sag.v.01
# merged bend.v.01 and lean.v.01
# merged twist.v.04 and intertwine.v.01
# merged separate.v.05 and sift.v.02
# merged break.v.02 and break_up.v.16
# merged integrate.v.03 and unify.v.01
# merged worsen.v.01 and devolve.v.03
# merged experience.v.03 and suffer.v.02
# merged think_of.v.04 and mention.v.01
# merged calculate.v.01 and estimate.v.01
# merged speculate.v.02 and guess.v.02
# merged categorize.v.01 and classify.v.01
# merged disapprove.v.02 and object.v.01
# merged think.v.01 and see.v.05
# merged measure.v.04 and praise.v.01
# merged meet.v.05 and satisfy.v.01
# merged forgive.v.01 and absolve.v.02
# merged resist.v.02 and defy.v.01
# merged save.v.02 and record.v.01
# merged deny.v.04 and withhold.v.01
# merged store.v.01 and roll_up.v.02
# merged insert.v.01 and implant.v.01
# merged copulate.v.01 and sleep_together.v.01
# merged trace.v.02 and write.v.07
# merged work.v.05 and till.v.01
# merged match.v.05 and balance.v.01
# merged reduce.v.01 and thin_out.v.01
# merged complete.v.01 and carry_through.v.01
# merged break.v.10 and interrupt.v.01
# merged impregnate.v.02 and soak.v.08
# merged hurt.v.02 and injure.v.01
# merged influence.v.01 and prejudice.v.02
# merged repair.v.01 and fill.v.09
# merged note.v.01 and comment.v.01
# merged present.v.02 and argue.v.01
# merged misrepresent.v.01 and feign.v.01
# merged rest.v.05 and sleep.v.01
# merged distinguish.v.01 and discriminate.v.02
# merged imagine.v.01 and visualize.v.01
# merged hurt.v.05 and humiliate.v.01
# merged interest.v.01 and absorb.v.09
# merged make.v.15 and fashion.v.01
# merged cook.v.02 and preserve.v.04
# merged regenerate.v.01 and replace.v.01
# merged care.v.02 and attend.v.02
# merged harass.v.01 and torment.v.02
# merged enclose.v.03 and encase.v.01
# merged ride.v.02 and boat.v.01
# merged address.v.09 and greet.v.01
# merged grip.v.01 and pinch.v.01
# merged catch.v.04 and fish.v.02
# merged bring.v.01 and impart.v.03
# merged hit.v.01 and shoot.v.08
# merged bring.v.04 and deliver.v.02
# merged convey.v.03 and communicate.v.01
# merged cram.v.02 and stuff.v.01
# merged position.v.01 and aim.v.01
# merged clasp.v.01 and embrace.v.02
# merged gamble.v.02 and bet.v.02
# merged label.v.01 and name.v.01
# merged exchange.v.01 and sell.v.01
# merged distribute.v.03 and issue.v.02
# merged check.v.01 and watch.v.02
# merged investigate.v.01 and probe.v.01
# merged discard.v.01 and abandon.v.01
# merged suppress.v.04 and inhibit.v.04
# merged choose.v.01 and specify.v.02
# merged create.v.03 and paint.v.01
# merged force.v.08 and pull.v.04
# merged wait.v.02 and delay.v.02
# merged reproduce.v.01 and imitate.v.01
# merged hold.v.11 and enclose.v.02
# merged change_posture.v.01 and sink.v.01
# merged leave.v.08 and leave_office.v.01
# merged reorient.v.03 and align.v.01
# merged transform.v.03 and become.v.02
# merged adjust.v.03 and obey.v.01
# merged modify.v.01 and corrupt.v.04
# merged discolor.v.03 and dye.v.01
# merged tighten.v.02 and compress.v.02
# merged dress.v.01 and wear.v.09
# merged denote.v.02 and name.v.02
# merged steal.v.01 and pilfer.v.01
# merged radiate.v.05 and flash.v.01
# merged sound.v.02 and make_noise.v.01
# merged concentrate.v.02 and steep.v.01
# merged think_about.v.01 and consider.v.03
# merged plan.v.02 and intend.v.02
# merged chew_over.v.01 and study.v.03
# merged associate.v.01 and think_of.v.04
# merged concede.v.02 and forgive.v.01
# merged conclude.v.03 and settle.v.03
# merged move_back_and_forth.v.01 and swing.v.02
# merged shake.v.01 and tremble.v.01
# merged jump.v.01 and bounce.v.01
# merged turn.v.09 and revolve.v.01
# merged charge.v.03 and levy.v.01
# merged attack.v.01 and bombard.v.02
# merged fight.v.02 and resist.v.02
# merged charm.v.02 and hex.v.01
# merged impede.v.01 and obstruct.v.02
# merged defend.v.02 and protect.v.01
# merged beat.v.01 and surpass.v.02
# merged destroy.v.01 and extinguish.v.04
# merged scat.v.01 and flee.v.01
# merged lie.v.01 and dominate.v.05
# merged shorten.v.03 and cut.v.32
# merged disable.v.01 and restrain.v.03
# merged mark.v.05 and trace.v.02
# merged transform.v.02 and work.v.05
# merged color.v.01 and tint.v.01
# merged develop.v.12 and grow.v.04
# merged wet.v.01 and drench.v.04
# merged damage.v.01 and mar.v.01
# merged empty.v.01 and hollow.v.02
# merged adjust.v.01 and match.v.05
# merged shape.v.03 and flatten.v.01
# merged worsen.v.02 and irritate.v.02
# merged clean.v.01 and wash.v.03
# merged affect.v.02 and stimulate.v.04
# merged represent.v.05 and misrepresent.v.01
# merged prove.v.02 and negate.v.03
# merged verify.v.01 and see.v.10
# merged delegate.v.02 and promote.v.02
# merged recumb.v.01 and rest.v.05
# merged spy.v.03 and detect.v.01
# merged exhale.v.01 and blow.v.01
# merged medicate.v.02 and drug.v.01
# merged discharge.v.02 and scatter.v.03
# merged capture.v.06 and hunt.v.01
# merged obtain.v.01 and procure.v.01
# merged confirm.v.02 and uphold.v.03
# merged identify.v.01 and distinguish.v.01
# merged produce.v.03 and leave.v.07
# merged create_verbally.v.01 and write.v.01
# merged produce.v.01 and give_birth.v.01
# merged help.v.01 and care.v.02
# merged disturb.v.01 and perturb.v.01
# merged annoy.v.01 and harass.v.01
# merged surround.v.01 and enclose.v.03
# merged cover.v.02 and flood.v.02
# merged travel_rapidly.v.01 and run.v.01
# merged advance.v.01 and pass.v.07
# merged walk.v.01 and march.v.01
# merged pursue.v.02 and chase.v.01
# merged travel.v.05 and ride.v.02
# merged come.v.01 and address.v.09
# merged pass.v.01 and traverse.v.01
# merged hang.v.06 and brood.v.02
# merged look.v.02 and rise.v.04
# merged confuse.v.02 and perplex.v.01
# merged rub.v.01 and wipe.v.01
# merged press.v.01 and squash.v.01
# merged strike.v.01 and beat.v.03
# merged stroke.v.01 and caress.v.01
# merged handle.v.04 and manipulate.v.02
# merged hit.v.02 and collide.v.03
# merged circulate.v.03 and spread.v.07
# merged pull.v.01 and attract.v.01
# merged transport.v.02 and bring.v.01
# merged push.v.01 and thrust.v.01
# merged transmit.v.04 and bring.v.04
# merged transfer.v.02 and convey.v.03
# merged recognize.v.04 and identify.v.06
# merged suffer.v.03 and grieve.v.01
# merged rejoice.v.01 and cheer.v.04
# merged grasp.v.01 and clasp.v.01
# merged race.v.02 and campaign.v.01
# merged play.v.01 and gamble.v.02
# merged designate.v.01 and label.v.01
# merged get_rid_of.v.01 and discard.v.01
# merged gain.v.05 and score.v.01
# merged forget.v.01 and suppress.v.04
# merged sound.v.06 and play.v.07
# merged sensitize.v.02 and stimulate.v.06
# merged leave.v.02 and abandon.v.05
# merged remember.v.02 and qualify.v.06
# merged produce.v.02 and reproduce.v.01
# merged include.v.01 and hold.v.11
# merged install.v.02 and invest.v.04
# merged remove.v.02 and displace.v.03
# merged perform.v.01 and interpret.v.03
# merged travel.v.03 and travel.v.02
# merged mean.v.03 and denote.v.02
# merged become.v.03 and originate.v.01
# merged learn.v.01 and study.v.05
# merged meet.v.02 and celebrate.v.02
# merged equal.v.01 and match.v.01
# merged account.v.02 and charge.v.03
# merged fail.v.02 and botch.v.01
# merged avoid.v.01 and hedge.v.01
# merged have.v.01 and keep.v.03
# merged join.v.01 and unite.v.01
# merged act.v.08 and play.v.05
# merged keep.v.01 and continue.v.03
# merged cultivate.v.01 and grow.v.07
# merged comfort.v.01 and calm.v.01
# merged dislike.v.01 and hate.v.01
# merged get_the_better_of.v.01 and beat.v.01
# merged unmake.v.01 and destroy.v.01
# merged attract.v.02 and capture.v.02
# merged hold.v.14 and behave.v.02
# merged leave.v.01 and scat.v.01
# merged fire.v.02 and blast.v.07
# merged start.v.10 and take_office.v.01
# merged act.v.02 and act_involuntarily.v.01
# merged beat.v.02 and flog.v.01
# merged insist.v.01 and assert.v.01
# merged give.v.08 and bequeath.v.01
# merged succeed.v.01 and achieve.v.01
# merged precipitate.v.03 and rain.v.01
# merged happen.v.01 and proceed.v.04
# merged appoint.v.02 and delegate.v.02
# merged succeed.v.02 and supplant.v.01
# merged lie.v.02 and recumb.v.01
# merged desire.v.01 and hanker.v.01
# merged kill.v.01 and murder.v.01
# merged gather.v.01 and pick.v.02
# merged determine.v.03 and identify.v.01
# merged charge.v.02 and accuse.v.01
# merged affect.v.05 and disturb.v.01
# merged save.v.03 and rescue.v.01
# merged hide.v.01 and obscure.v.01
# merged take.v.08 and deprive.v.01
# merged guide.v.05 and rub.v.01
# merged meet.v.10 and confront.v.01
# merged remember.v.01 and recognize.v.04
# merged separate.v.07 and break.v.05
# merged hold.v.02 and grasp.v.01
# merged arrive.v.01 and land.v.01

# %%
def _verb_to_gemma_vocab_elements(verb):
    #  add in regular verb conjugations to expand vocab
 
    verb = verb.lower()

    # some weird wordnet bugs, filter it
    if len(verb) < 3 and verb not in ["be", "do", "go"]:
        return set()

    # Conjugating to past tense
    if verb.endswith('e'):
        past = verb + 'd'
    else:
        past = verb + 'ed'
    
    # Conjugating to present participle
    if verb.endswith('e'):
        present_participle = verb[:-1] + 'ing'
    else:
        present_participle = verb + 'ing'
    
    # 3psg 
    if verb.endswith(("o", "ch", "s", "sh", "x", "z")):
        third_person = verb + 'es'
    elif verb.endswith("y") and verb[-2] not in "aeiou":
        third_person = verb[:-1] + 'ies'
    else:
        third_person = verb + 's'


    tenses = [verb, past, present_participle, third_person]

    caps = [w.capitalize() for w in tenses]
    
    # Add underscore prefix to each word to match vocab tokens
    add_space = ["▁" + w for w in (caps + tenses)]

    # Return intersection with a hypothetical vocabulary set
    return vocab_set.intersection(add_space)

### save the data
# with open('data/verb_synsets_wordnet_gemma.json', 'w') as f:
#     for synset, lemmas in large_verbs.items():
#         gemma_words = []
#         for w in lemmas:
#             gemma_words.extend(_verb_to_gemma_vocab_elements(w))

#         f.write(json.dumps({synset: gemma_words}) + "\n")
        
# nx.write_adjlist(G_verb, "data/verb_synsets_wordnet_hypernym_graph.adjlist")
